# %% [markdown]
# # Assignment 1 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %%
from IPython.display import Image
Image("Task2-2a.png")

# %% [markdown]
# ## task 1b)
#
# Fill in task 1a image of hand-written notes which are easy to read, or latex equations here

# %%
Image("Task2-2b1.png")

# %%
Image("Task2-2b2.png")

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Task 2c)
# ![](task2c_train_loss.png)

# %%
#2A Mean: 33.55274553571429 , STD:  78.87550070784701

Image("2C_task2c_train_loss.png")

# %% [markdown]
# ## Task 2d)
# FILL IN ANSWER

# %% [markdown]
# 785*64+64*10 = 50 880

# %% [markdown]
# # Task 3

# %% [markdown]
# FILL IN ANSWER.
# Maybe include a loss / accuracy plot here?

# %%
Image("3siste.png")

# %% [markdown]
# As we can see from the graph above, the preformance improved over time. We started by adding the imroved weight, then we added the improved sigmoid, and lastly we added the momentum.
# We saw the biggest difference and best improvement after adding the improved weights. This addition improved the validation loss, and the valitation accuricy in adition to converging faster. There were no big differences in overfitting og underfitting, but the early-stopping kicked in earlier than the original. After adding the improved Sigmoid, we saw a much faster learning rate and early stopping kicked in way before the original model.
#
#
#
#
#
#
#
# etter sigmoid - så vi en much faster learning rate and early stopping kikec in lenge før den originale og tidligere modellen. men forskjellen i validation loss og trenings loss var mer signifikant. dette kan være et tegn på overfitting
#
#
# største forbedring ved improved waightns - forbedret vlidation loss og accuricy i tillegg til raskere konvergens.
#
# ingen store endringer forskjeller  i over eller under-fitting
# early stopping kicket inn tidligere enn den originale modellen
#
# momentum  til gradient update stop - reduserte learningrate
# modellen ble overaskende nok mer lik som før sigmoid
#
# konvergerer ganske likt som før, men early stopping slår også inn raskere

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
#
# FILL IN ANSWER.

# %%
Image("4A.png")

# %% [markdown]
# ## Task 4b)
# FILL IN ANSWER

# %%
Image("4B.png")

# %% [markdown]
# ## Task 4d)
# FILL IN ANSWER

# %% [markdown]
# ## Task 4e)
# FILL IN ANSWER
